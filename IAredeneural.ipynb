# %%
import torch

# %%
import torchvision

# %%
import torchvision.transforms as transforms

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)) #(x - (0.5) / 0.5)
])
train_dataset = torchvision.datasets.CIFAR10(
    root="./data", train=True, download=True, transform=transform
)
test_dataset = torchvision.datasets.CIFAR10(
    root="./data", train=False, download=True, transform=transform
)

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
import torch.nn as nn
import torch

class CNNSimples(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)

        self.pool = nn.MaxPool2d(2, 2)

        self.fc1 = nn.Linear(16 * 16 * 16, 10)

    def forward(self, x):
        x = self.conv1(x)

        x = torch.relu(x)

        x = self.pool(x)

        x = x.view(x.size(0), -1)

        x = self.fc1(x)

        return x

# %%
model = CNNSimples()

# %%
import torch.optim as optim
import torch.nn as nn

criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(
    model.parameters(),
    lr=0.001
)

# %%
for epoch in range(10):

    for images, labels in train_loader:

        optimizer.zero_grad()

        outputs = model(images)

        loss = criterion(outputs, labels)

        loss.backward()

        optimizer.step()

    print(f"Epoch {epoch+1}, Loss: {loss.item()}")
# Out:
# Epoch 1, Loss: 0.9729201793670654
# Epoch 2, Loss: 1.2348562479019165
# Epoch 3, Loss: 1.1329374313354492
# Epoch 4, Loss: 1.4481185674667358
# Epoch 5, Loss: 1.0781822204589844
# Epoch 6, Loss: 0.8477576375007629
# Epoch 7, Loss: 1.5964221954345703
# Epoch 8, Loss: 1.2168550491333008
# Epoch 9, Loss: 0.828289270401001
# Epoch 10, Loss: 1.159462571144104

# %%
correct = 0
total = 0

with torch.no_grad():

    for images, labels in test_loader:
        outputs = model(images)

        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)

        correct += (predicted == labels).sum().item()


accuracy = 100 * correct / total

print(f"Acurácia no teste: {accuracy:.2f}%")
# Out:
# Acurácia no teste: 62.36%
